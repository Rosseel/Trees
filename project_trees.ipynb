# %%
import pandas as pd

# %%
df=pd.read_csv('trees.csv',index_col='the_geom')
print(df.shape)
#No duplicates.  
df.drop_duplicates(inplace=True)
print(df.shape)
df.head()
# Out:
# (683788, 41)
# (683788, 41)
#                                                created_at  tree_id  block_id  \
# the_geom
# POINT (-73.84421521958048 40.723091773924274)  08/27/2015   180683    348711
# POINT (-73.81867945834878 40.79411066708779)   09/03/2015   200540    315986
# POINT (-73.93660770459083 40.717580740099116)  09/05/2015   204026    218365
# POINT (-73.93445615919741 40.713537494833226)  09/05/2015   204337    217969
# POINT (-73.97597938483258 40.66677775537875)   08/30/2015   189565    223043
#
#                                                tree_dbh  stump_diam curb_loc  \
# the_geom
# POINT (-73.84421521958048 40.723091773924274)         3           0   OnCurb
# POINT (-73.81867945834878 40.79411066708779)         21           0   OnCurb
# POINT (-73.93660770459083 40.717580740099116)         3           0   OnCurb
# POINT (-73.93445615919741 40.713537494833226)        10           0   OnCurb
# ...

# %%
# print(df.isnull().sum())
# print(df.isna().sum())
print(df.shape)
# The dataset contains no missing values ("" or null)  
# Can you fill in some missing values ?
df.dropna(inplace=True)
print(df.shape)
# Out:
# (683788, 41)
# (652118, 41)

# %%
df.head().T
# Out:
# the_geom   POINT (-73.84421521958048 40.723091773924274)  \
# created_at                                    08/27/2015
# tree_id                                           180683
# block_id                                          348711
# tree_dbh                                               3
# stump_diam                                             0
# curb_loc                                          OnCurb
# status                                             Alive
# health                                              Fair
# spc_latin                                    Acer rubrum
# spc_common                                     red maple
# steward                                             None
# guards                                              None
# sidewalk                                        NoDamage
# user_type                               TreesCount Staff
# problems                                            None
# ...

# %%
for idx,name in enumerate(df):
    print(df[name].value_counts())
# Out:
# 10/27/2015    6494
# 10/13/2015    6328
# 10/29/2015    5942
# 10/26/2015    5925
# 11/03/2015    5712
#               ...
# 02/13/2016       9
# 03/02/2016       6
# 10/04/2016       6
# 04/03/2016       4
# 03/14/2016       2
# Name: created_at, Length: 483, dtype: int64
# 2047      1
# 366616    1
# 368671    1
# 370718    1
# 372765    1
#          ..
# 466358    1
# 460213    1
# 462260    1
# 472499    1
# 2049      1
# Name: tree_id, Length: 652118, dtype: int64
# 204850    440
# 602362    356
# 208115    241
# 506756    206
# 233208    194
#          ...
# 300658      1
# 314812      1
# 312101      1
# 102881      1
# 107219      1
# Name: block_id, Length: 100693, dtype: int64
# 4      58146
# 3      51620
# 5      40701
# 2      38480
# 11     37584
#        ...
# 75         1
# 151        1
# 154        1
# 159        1
# 425        1
# Name: tree_dbh, Length: 145, dtype: int64
# 0    652118
# Name: stump_diam, dtype: int64
# OnCurb            626254
# ...

# %%
print(df.dtypes)
# Out:
# created_at     object
# tree_id         int64
# block_id        int64
# tree_dbh        int64
# stump_diam      int64
# curb_loc       object
# status         object
# health         object
# spc_latin      object
# spc_common     object
# steward        object
# guards         object
# sidewalk       object
# user_type      object
# problems       object
# root_stone     object
# root_grate     object
# root_other     object
# trnk_wire      object
# trnk_light     object
# trnk_other     object
# brnch_ligh     object
# brnch_shoe     object
# brnch_othe     object
# address        object
# zipcode         int64
# zip_city       object
# cb_num          int64
# borocode        int64
# boroname       object
# cncldist        int64
# st_assem        int64
# st_senate       int64
# nta            object
# nta_name       object
# boro_ct         int64
# state          object
# Latitude      float64
# longitude     float64
# x_sp          float64
# y_sp          float64
# dtype: object

# %%
# Is the date format correct?
df['created_at'] = df['created_at'].astype('datetime64[ns]')


# No blank spaces (ex: " I love python " => "I love python")
df['spc_latin'] = df['spc_latin'].str.strip()
df['spc_common'] = df['spc_common'].str.strip()

# Are there some columns where most of the data is missing ? => all same value
df.drop('status',axis=1)
df.drop('stump_diam',axis=1)

#Can values be consolidated? (e.g. Truck and truck refer to the same thing) => opposite in column problems
#No
# Are some values integers that should be float or vice-versa ? Change the dtype.
#No
# Out:
#                                               created_at  tree_id  block_id  \
# the_geom
# POINT (-73.84421521958048 40.723091773924274) 2015-08-27   180683    348711
# POINT (-73.81867945834878 40.79411066708779)  2015-09-03   200540    315986
# POINT (-73.93660770459083 40.717580740099116) 2015-09-05   204026    218365
# POINT (-73.93445615919741 40.713537494833226) 2015-09-05   204337    217969
# POINT (-73.97597938483258 40.66677775537875)  2015-08-30   189565    223043
# ...                                                  ...      ...       ...
# POINT (-73.95494401022562 40.7132107823145)   2015-08-18   155433    217978
# POINT (-73.85665019989099 40.71519444267162)  2015-08-29   183795    348185
# POINT (-74.13651724205825 40.62076152739799)  2015-08-22   166161    401670
# POINT (-73.90311472453581 40.850828186655754) 2015-08-29   184028    504204
# POINT (-73.78752645502483 40.73216525220126)  2015-09-03   200607    306527
#
# ...
